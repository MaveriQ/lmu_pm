# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])

# %%
df.head()
# Out:
#           x         y
# 0  1.202393  0.681589
# 1  0.063490  1.020887
# 2  2.625187  1.841843
# 3  0.452484  0.216652
# 4 -0.950321  0.060545

# %%
with sns.axes_style("white"):
    sns.jointplot(x=df.x, y=df.y, color="k");

# %%
sns.jointplot(x="x", y="y", data=df, kind="kde");

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.kdeplot(df.x, df.y, ax=ax);

# %% [markdown]
# ### Fixing shapes of theta and x with expand_dims

# %%
theta=np.linspace(-2,2,5)
theta1, theta2 = np.meshgrid(theta, theta)
x=np.linspace(0,2,3)
y=np.linspace(2,4,3)

# %%
theta1
# Out:
# array([[-2., -1.,  0.,  1.,  2.],
#        [-2., -1.,  0.,  1.,  2.],
#        [-2., -1.,  0.,  1.,  2.],
#        [-2., -1.,  0.,  1.,  2.],
#        [-2., -1.,  0.,  1.,  2.]])

# %%
x,y
# Out:
# (array([0., 1., 2.]), array([2., 3., 4.]))

# %%
theta=np.expand_dims(theta1,2)

# %%
theta.shape,x.shape
# Out:
# ((5, 5, 1), (3,))

# %%
y_h=theta*x
reg=theta*theta
y_h_r=y_h+reg
y_h.shape
# Out:
# (5, 5, 3)

# %%
theta.shape,y_h.shape
# Out:
# ((5, 5, 1), (5, 5, 3))

# %%
y_h[:,:,1],theta[:,:,0]*theta[:,:,0],y_h_r[:,:,1]
# Out:
# (array([[-2., -1.,  0.,  1.,  2.],
#         [-2., -1.,  0.,  1.,  2.],
#         [-2., -1.,  0.,  1.,  2.],
#         [-2., -1.,  0.,  1.,  2.],
#         [-2., -1.,  0.,  1.,  2.]]),
#  array([[4., 1., 0., 1., 4.],
#         [4., 1., 0., 1., 4.],
#         [4., 1., 0., 1., 4.],
#         [4., 1., 0., 1., 4.],
#         [4., 1., 0., 1., 4.]]),
#  array([[2., 0., 0., 2., 6.],
#         [2., 0., 0., 2., 6.],
#         [2., 0., 0., 2., 6.],
#         [2., 0., 0., 2., 6.],
#         [2., 0., 0., 2., 6.]]))

# %%
diff=y_h-y

# %%
diff[:,:,1]
# Out:
# array([[-5., -4., -3., -2., -1.],
#        [-5., -4., -3., -2., -1.],
#        [-5., -4., -3., -2., -1.],
#        [-5., -4., -3., -2., -1.],
#        [-5., -4., -3., -2., -1.]])

# %%
theta1*theta1
# Out:
# array([[4., 1., 0., 1., 4.],
#        [4., 1., 0., 1., 4.],
#        [4., 1., 0., 1., 4.],
#        [4., 1., 0., 1., 4.],
#        [4., 1., 0., 1., 4.]])
